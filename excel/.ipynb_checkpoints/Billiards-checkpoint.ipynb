# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
bill = pd.read_csv('C://Users//Owner//DA//Weekly Projects//skills_practice//excel//billiard_angles.csv')

# %%
bill
# Out:
#     degree    trig (cos)      x    gap gap % gap frac 1x gap frac 2x  overlap  \
# 0       90  6.125740e-17  0.000  1.125    0%       0         0            NaN
# 1       89  1.745241e-02  0.020  1.085    4%       0            1/28      NaN
# 2       88  3.489950e-02  0.039  1.047    7%       0            5/72      NaN
# 3       87  5.233596e-02  0.059  1.007   10%         1/9        2/19      NaN
# 4       86  6.975647e-02  0.078  0.969   14%         1/7        5/36      NaN
# ..     ...           ...    ...    ...   ...         ...         ...      ...
# 86       4  9.975641e-01  1.122    NaN   NaN         NaN         NaN    1.119
# 87       3  9.986295e-01  1.123    NaN   NaN         NaN         NaN    1.121
# 88       2  9.993908e-01  1.124    NaN   NaN         NaN         NaN    1.123
# 89       1  9.998477e-01  1.125    NaN   NaN         NaN         NaN    1.125
# 90       0  1.000000e+00  1.125    NaN   NaN         NaN         NaN    1.125
#
# ...

# %%
plt.scatter(x='degree',y='gap by degree')

# %%
plt.plot(bill['degree'],bill['gap by degree'], marker='x', color = 'green')
plt.title('Changes in Displacement by Degree')
plt.xlabel('Degree of Contact Angle')
plt.ylabel('Change in Location')
plt.show()
