# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import regex as re
import time

# %%
url='https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2000'

# %%
requests.get(url)
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Billboard Year-End Hot 100 singles of 2000 - Wikipedia\n  </title>\n  <script>\n   document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"10e316b0-06c6-4468-9ce8-14432def41b2","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_2000","wgTitle":"Billboard Year-End Hot 100 singles of 2000","wgCurRevisionId":1100830105,"wgRevisionId":1100830105,"wgArticleId":18580928,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["2000 record charts","Billboard chart
# ...

# %%
soup.find_all('td')
# Out:
# [<td>1</td>,
#  <td>"<a href="/wiki/Breathe_(Faith_Hill_song)" title="Breathe (Faith Hill song)">Breathe</a>"</td>,
#  <td><a href="/wiki/Faith_Hill" title="Faith Hill">Faith Hill</a>
#  </td>,
#  <td>2</td>,
#  <td>"<a href="/wiki/Smooth_(Santana_song)" title="Smooth (Santana song)">Smooth</a>"</td>,
#  <td><a href="/wiki/Santana_(band)" title="Santana (band)">Santana</a> featuring <a href="/wiki/Rob_Thomas_(musician)" title="Rob Thomas (musician)">Rob Thomas</a>
#  </td>,
#  <td>3</td>,
#  <td>"<a href="/wiki/Maria_Maria" title="Maria Maria">Maria Maria</a>"</td>,
#  <td><a href="/wiki/Santana_(band)" title="Santana (band)">Santana</a> featuring <a href="/wiki/The_Product_G%26B" title="The Product G&amp;B">The Product G&amp;B</a>
#  </td>,
#  <td>4</td>,
#  <td>"<a href="/wiki/I_Wanna_Know_(Joe_song)" title="I Wanna Know (Joe song)">I Wanna Know</a>"</td>,
#  <td><a href="/wiki/Joe_(singer)" title="Joe (singer)">Joe</a>
#  </td>,
#  <td>5</td>,
# ...

# %%
len(soup.find_all('td')[0].text.strip())
# Out:
# 1

# %%
len(soup.find_all('td'))
# Out:
# 305

# %%
for i in range(305):
    print(len(soup.find_all('td')[i]))
# Out:
# 1
# 3
# 2
# 1
# 3
# 4
# 1
# 3
# 4
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 8
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 6
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 4
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 4
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 4
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 4
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 4
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1
# ...

# %%
url='https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2000'

# %%
year = []

# %%
for i in range(10):
    print(soup.find_all('td')[i].text.strip())
# Out:
# 1
# "Breathe"
# Faith Hill
# 2
# "Smooth"
# Santana featuring Rob Thomas
# 3
# "Maria Maria"
# Santana featuring The Product G&B
# 4

# %%
rank = []
songs = []
artists = []

# %%
a=0
b=1
c=1
for i in range (300):
    
    if  c==0:
        songs.append(soup.find_all('td')[i].text.strip())
        b+=1
        a=0
        c+=1
    elif b == 0:
        artists.append(soup.find_all('td')[i].text.strip())
        a=+1
        b+=1
        c=0
    elif a == 0:
        rank.append(soup.find_all('td')[i].text.strip())
        b=0
        c+=1
        a+=1
    else: print(soup.find_all('td')[i].text.strip(),'is not used')

# %%
print(len(songs),len(artists),len(rank))
# Out:
# 100 100 100

# %%
print(songs, artists)
# Out:
# ['Faith Hill', 'Santana featuring Rob Thomas', 'Santana featuring The Product G&B', 'Joe', 'Vertical Horizon', "Destiny's Child", 'Savage Garden', 'Lonestar', 'Matchbox Twenty', 'Toni Braxton', 'Creed', 'Aaliyah', "Destiny's Child", 'Sisqó', '3 Doors Down', 'Pink', 'Madonna', 'Janet', 'Christina Aguilera', 'Brian McKnight', "'N Sync", 'Marc Anthony', 'Marc Anthony', 'Montell Jordan', 'Sisqó', 'Macy Gray', "'N Sync", 'Céline Dion', 'Nelly', 'Blaque', 'Backstreet Boys', 'Missy Elliott featuring Nas, Eve and Q-Tip', 'BBMak', 'Sonique', 'Nine Days', 'Creed', 'Enrique Iglesias', 'Christina Aguilera', 'Ruff Endz', 'Blink 182', 'Faith Hill', 'Christina Aguilera', 'Third Eye Blind', 'LeAnn Rimes', 'Mariah Carey featuring Joe and 98 Degrees', 'Jagged Edge', 'Whitney Houston', 'Smash Mouth', 'Eiffel 65', 'Sting featuring Cheb Mami', 'Eminem', 'Pink', 'Next', 'Everclear', 'Britney Spears', 'Jessica Simpson', '98 Degrees', 'Filter', 'Red Hot Chili Peppers', 'Jay-Z featuring UGK', 'Son by Four', 
# ...

# %%
music = pd.DataFrame([rank,songs,artists]).T

# %%
music.columns = ['Rank','Songs','Artists']

# %%
music
# Out:
#    Rank                              Songs                     Artists
# 0     1                         Faith Hill                   "Breathe"
# 1     2       Santana featuring Rob Thomas                    "Smooth"
# 2     3  Santana featuring The Product G&B               "Maria Maria"
# 3     4                                Joe              "I Wanna Know"
# 4     5                   Vertical Horizon       "Everything You Want"
# ..  ...                                ...                         ...
# 95   96                            Aaliyah             "I Don't Wanna"
# 96   97                    Destiny's Child  "Independent Women Part I"
# 97   98                     Samantha Mumba            "Gotta Tell You"
# 98   99                     Jennifer Lopez       "Waiting for Tonight"
# 99  100                          Mary Mary     "Shackles (Praise You)"
#
# [100 rows x 3 columns]

# %%
year=[]
for i in range(2000,2010,1):
    year.append(str(i))

# %%
year
# Out:
# ['2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009']

# %%
a=len(year)
a
# Out:
# 10

# %%
for i in range(len(year)):
    url='https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_'+ year[i]
    print(url)
# Out:
# https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2000
# https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2001
# https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2002
# https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2003
# https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2004
# https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2005
# https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2006
# https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2007
# https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2008
# https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2009

# %%
pages = []
for i in range(len(year)):
    url='https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_'+ year[i]
    # download html with a get request:
    response = requests.get(url)
    # monitor the process by printing the status code
    print("Status code: " + str(response.status_code))
    soup = BeautifulSoup(response.content, 'html.parser')
    
    pages.append(response)
    # respectful nap:
    wait_time = 2
    print("I will sleep for " + str(wait_time) + " second/s.")
    time.sleep(wait_time)
# Out:
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.

# %%
len(soup)
# Out:
# 3

# %%
totrank=[]
totsongs=[]
totartists=[]

# %%
len(songs.append(soup.find_all('td')[)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21088/3357423783.py in <module>
# ----> 1 len(songs.append(soup.find_all('td')[i].text.strip()))
#
# TypeError: object of type 'NoneType' has no len()

# %%
a=0
b=1
c=1
for i in range (300):
    
    if  c==0:
        songs.append(soup.find_all('td')[i].text.strip())
        b+=1
        a=0
        c+=1
    elif b == 0:
        artists.append(soup.find_all('td')[i].text.strip())
        a=+1
        b+=1
        c=0
    elif a == 0:
        rank.append(soup.find_all('td')[i].text.strip())
        b=0
        c+=1
        a+=1
    else: print(soup.find_all('td')[i].text.strip(),'is not used')
