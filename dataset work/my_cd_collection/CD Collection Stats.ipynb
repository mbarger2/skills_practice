# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',None)

# %%
data = pd.read_excel('C:/Users/Owner/Documents/CDS.xlsx')

# %%
data.head()
# Out:
#    Unnamed: 0               Artist                    Album    Year
# 0         NaN                  NaN                      NaN     NaN
# 1         NaN  "Weird Al" Yankovic        Dare to be Stupid  1985.0
# 2         NaN  "Weird Al" Yankovic               Alapalooza  2003.0
# 3         NaN  "Weird Al" Yankovic            Mandatory Fun  2014.0
# 4         NaN             10 Years  (How to Live) As Ghosts  2017.0

# %%
data.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
data.head()
# Out:
#                 Artist                    Album    Year
# 0                  NaN                      NaN     NaN
# 1  "Weird Al" Yankovic        Dare to be Stupid  1985.0
# 2  "Weird Al" Yankovic               Alapalooza  2003.0
# 3  "Weird Al" Yankovic            Mandatory Fun  2014.0
# 4             10 Years  (How to Live) As Ghosts  2017.0

# %%
data=data.T

# %%
data.head()
# Out:
#         0                    1                    2                    3    \
# Artist  NaN  "Weird Al" Yankovic  "Weird Al" Yankovic  "Weird Al" Yankovic
# Album   NaN    Dare to be Stupid           Alapalooza        Mandatory Fun
# Year    NaN               1985.0               2003.0               2014.0
#
#                             4                5                  6    \
# Artist                 10 Years     3 Doors Down       3 Doors Down
# Album   (How to Live) As Ghosts  The Better Life  Away From The Sun
# Year                     2017.0           2000.0             2002.0
#
#                       7                    8                           9    \
# Artist       3 Doors Down  5 Seconds of Summer           A Day to Remember
# Album   Away From the Sun                 Five  What Separates You From Me
# Year               2002.0               2014.0                      2010.0
#
#                       10                11                12   \
# ...

# %%
data.drop(0,axis=1,inplace=True)

# %%
data=data.T
data.head()
# Out:
#                 Artist                    Album    Year
# 1  "Weird Al" Yankovic        Dare to be Stupid  1985.0
# 2  "Weird Al" Yankovic               Alapalooza  2003.0
# 3  "Weird Al" Yankovic            Mandatory Fun  2014.0
# 4             10 Years  (How to Live) As Ghosts  2017.0
# 5         3 Doors Down          The Better Life  2000.0

# %%
data['Year'].isna().sum()
# Out:
# 1

# %%
data.tail()
# Out:
#                 Artist                                 Album    Year
# 287  We Came as Romans  Understanding What We've Grown to be  2011.0
# 288  We Came as Romans                    Tracing Back Roots  2013.0
# 289  We Came as Romans                     We Came as Romans  2015.0
# 290  We Came as Romans                         Cold Like War  2017.0
# 291             Weezer                        The Blue Album  1994.0

# %%
data.head()
# Out:
#                 Artist                    Album    Year
# 1  "Weird Al" Yankovic        Dare to be Stupid  1985.0
# 2  "Weird Al" Yankovic               Alapalooza  2003.0
# 3  "Weird Al" Yankovic            Mandatory Fun  2014.0
# 4             10 Years  (How to Live) As Ghosts  2017.0
# 5         3 Doors Down          The Better Life  2000.0

# %%
data[data['Year'].isna()]
# Out:
#            Artist          Album Year
# 44  Beyond Repair  Things Change  NaN

# %%
data['Year']=data['Year'].replace(np.nan,0)

# %%
data
# Out:
#                                    Artist  \
# 1                     "Weird Al" Yankovic
# 2                     "Weird Al" Yankovic
# 3                     "Weird Al" Yankovic
# 4                                10 Years
# 5                            3 Doors Down
# 6                            3 Doors Down
# 7                            3 Doors Down
# 8                     5 Seconds of Summer
# 9                       A Day to Remember
# 10                      A Day to Remember
# 11                       A Perfect Circle
# 12                       A Perfect Circle
# 13                       A Perfect Circle
# 14                       A Perfect Murder
# 15                          Acacia Strain
# 16                          Acacia Strain
# 17                          Acacia Strain
# 18                      Alanis Morissette
# 19                                Alesana
# 20                                Alesana
# 21                                Alesana
# ...

# %%
data[data['Artist']=='Beyond Repair']
# Out:
#            Artist          Album  Year
# 44  Beyond Repair  Things Change   0.0

# %%
data['Year']=list(map(lambda x: int(round(x,0)),data['Year']))

# %%
data.isna().sum()
# Out:
# Artist    0
# Album     0
# Year      0
# dtype: int64

# %%
data.head()
# Out:
#                 Artist                    Album  Year
# 1  "Weird Al" Yankovic        Dare to be Stupid  1985
# 2  "Weird Al" Yankovic               Alapalooza  2003
# 3  "Weird Al" Yankovic            Mandatory Fun  2014
# 4             10 Years  (How to Live) As Ghosts  2017
# 5         3 Doors Down          The Better Life  2000

# %%
data.loc[44]
# Out:
# Artist    Beyond Repair
# Album     Things Change
# Year                  0
# Name: 44, dtype: object

# %%
data['Year'].nunique()
# Out:
# 38

# %%
data['Year'].unique()
# Out:
# array([1985, 2003, 2014, 2017, 2000, 2002, 2010, 2013, 2018, 2005, 2012,
#        1995, 2008, 2011, 1994, 2001, 1998, 2015, 2006, 2007, 2004,    0,
#        1970, 1973, 1999, 1993, 1996, 2016, 1997, 1992, 2009, 2019, 1990,
#        1977, 1991, 1981, 1989, 1964], dtype=int64)

# %%
data['Artist'].nunique()
# Out:
# 177

# %%
cdat1=data['Artist'].value_counts()
cdat1
# Out:
# Senses Fail                             8
# Nickelback                              7
# Lamb of God                             7
# Various Artists                         6
# DevilDriver                             5
# New Found Glory                         5
# We Came as Romans                       4
# Mudvayne                                4
# Brand New                               4
# Blink 182                               3
# Slipknot                                3
# Puddle of Mudd                          3
# Sum 41                                  3
# "Weird Al" Yankovic                     3
# Stone Temple Pilots                     3
# Rush                                    3
# Butthole Surfers                        3
# Chimaira                                3
# Drowning Pool                           3
# Crossfade                               3
# Alkaline Trio                           3
# 3 Doors Down                            3
# ...

# %%
#create dictionary of artist to cds owned of artist to apply to new column in original table

# %%
cts= pd.DataFrame (cdat1, columns = ['Artist','CD Count'])
cts
# Out:
#                                       Artist CD Count
# Senses Fail                                8      NaN
# Nickelback                                 7      NaN
# Lamb of God                                7      NaN
# Various Artists                            6      NaN
# DevilDriver                                5      NaN
# New Found Glory                            5      NaN
# We Came as Romans                          4      NaN
# Mudvayne                                   4      NaN
# Brand New                                  4      NaN
# Blink 182                                  3      NaN
# Slipknot                                   3      NaN
# Puddle of Mudd                             3      NaN
# Sum 41                                     3      NaN
# "Weird Al" Yankovic                        3      NaN
# Stone Temple Pilots                        3      NaN
# Rush                                       3      NaN
# ...

# %%
cts=cts.reset_index()
cts
# Out:
#                                     index  Artist CD Count
# 0                             Senses Fail       8      NaN
# 1                              Nickelback       7      NaN
# 2                             Lamb of God       7      NaN
# 3                         Various Artists       6      NaN
# 4                             DevilDriver       5      NaN
# 5                         New Found Glory       5      NaN
# 6                       We Came as Romans       4      NaN
# 7                                Mudvayne       4      NaN
# 8                               Brand New       4      NaN
# 9                               Blink 182       3      NaN
# 10                               Slipknot       3      NaN
# 11                         Puddle of Mudd       3      NaN
# 12                                 Sum 41       3      NaN
# 13                    "Weird Al" Yankovic       3      NaN
# 14                    Stone Temple Pilots       3      NaN
# ...

# %%
cts.drop(['CD Count'],axis=1,inplace=True)

# %%
cts.head()
# Out:
#              index  Artist
# 0      Senses Fail       8
# 1       Nickelback       7
# 2      Lamb of God       7
# 3  Various Artists       6
# 4      DevilDriver       5

# %%
cts.columns=['Artist','CD Count']

# %%
cts.head()
# Out:
#             Artist  CD Count
# 0      Senses Fail         8
# 1       Nickelback         7
# 2      Lamb of God         7
# 3  Various Artists         6
# 4      DevilDriver         5

# %%
cts2=cts['CD Count'].value_counts()
cts2
# Out:
# 1    113
# 2     37
# 3     18
# 4      3
# 7      2
# 5      2
# 8      1
# 6      1
# Name: CD Count, dtype: int64

# %%
cts3= pd.DataFrame (cts2, columns = ['CD Count'])
cts3
# Out:
#    CD Count
# 1       113
# 2        37
# 3        18
# 4         3
# 7         2
# 5         2
# 8         1
# 6         1

# %%
cts3.index.name='Instances'
cts3
# Out:
#            CD Count
# Instances
# 1               113
# 2                37
# 3                18
# 4                 3
# 7                 2
# 5                 2
# 8                 1
# 6                 1

# %%
cts3=cts3.reset_index()
cts3
# Out:
#    Instances  CD Count
# 0          1       113
# 1          2        37
# 2          3        18
# 3          4         3
# 4          7         2
# 5          5         2
# 6          8         1
# 7          6         1

# %%
plt.bar(cts3['Instances'],cts3['CD Count'],color=(0.5,0.01,0.2))
plt.title('How Many CDs Do I Own of Each Artist in My Collection')
plt.xlabel('Number of CDs of Each Artist')
plt.ylabel('Instances')
plt.show()

# %%
#create dictionary of this to apply to new column

# %%
acdct={}
for i in cts['Artist']:
    acdct[i]=cts[cts['Artist']==i]['CD Count'].values[0]

# %%
def get_cd_count(x):
    storelist=list(acdct.keys())
    if (x in storelist):
        return acdct[x]
    else:
        return '0'

# %%
data['Total CDs']=list(map(get_cd_count,data['Artist']))

# %%
acdct['"Weird Al" Yankovic']
# Out:
# 3

# %%
data.head()
# Out:
#                 Artist                    Album  Year  Total CDs
# 1  "Weird Al" Yankovic        Dare to be Stupid  1985          3
# 2  "Weird Al" Yankovic               Alapalooza  2003          3
# 3  "Weird Al" Yankovic            Mandatory Fun  2014          3
# 4             10 Years  (How to Live) As Ghosts  2017          1
# 5         3 Doors Down          The Better Life  2000          3

# %%
ct4=data['Year'].value_counts()
ct5=pd.DataFrame(ct4,columns=['Year'])
ct5.index.name='Years'
ct5=ct5.T
ct5.drop([0],axis=1,inplace=True)
ct5=ct5.T
ct5=ct5.reset_index()
ct5
# Out:
#     Years  Year
# 0    2006    29
# 1    2005    24
# 2    2004    20
# 3    2001    19
# 4    2003    16
# 5    2011    14
# 6    2008    14
# 7    2002    12
# 8    2007    11
# 9    2013    11
# 10   2010     9
# 11   2000     9
# 12   1994     9
# 13   2018     9
# 14   2015     7
# 15   1996     7
# 16   2009     7
# 17   1992     6
# 18   1997     6
# 19   2012     6
# 20   2014     6
# 21   2016     5
# 22   1998     5
# 23   1995     5
# 24   2017     5
# 25   1999     4
# 26   1991     3
# 27   1993     3
# 28   1981     1
# 29   1989     1
# 30   1990     1
# 31   1977     1
# 32   1985     1
# 33   2019     1
# 34   1973     1
# 35   1970     1
# 36   1964     1

# %%
#rename columns 
cnames=['Years','Instances']
ct5.columns=cnames

# %%
ct5.head()
# Out:
#    Years  Instances
# 0   2006         29
# 1   2005         24
# 2   2004         20
# 3   2001         19
# 4   2003         16

# %%
plt.bar(ct5['Years'],ct5['Instances'],color=(0.3,0.9,0.6))
plt.title('Categorizing My Owned Albums by Release Year')
plt.xlabel('Release Year')
plt.ylabel('Albums Owned')
plt.show()
plt.show()

# %%
# use notes to plot normal distribution of above plot

# %%
sns.distplot(ct5['Years'])
plt.show()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(ct5['Years'],bins=30)
plt.show()

# %%
sns.histplot(ct5['Years'])
plt.show()

# %%
sns.distplot(ct5['Instances'])
plt.show()

# %%
sns.kdeplot(data=ct5['Instances'], x=ct5['Years'])
sns.rugplot(data=ct5['Instances'], x=ct5['Years'])
# Out:
# <AxesSubplot:xlabel='Years', ylabel='Density'>

# %%
sns.distplot(ct5['Instances'], rug=True, rug_kws={"color": "b", "linewidth":2},
                  kde_kws={"color": "r", "lw": 2, "label": "KDE"},
                  hist_kws={"histtype": "step", "linewidth":2,"alpha": 1, "color": "g"})
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Instances', ylabel='Density'>

# %%
# add new data in 
#slall.to_csv('storenumlocation.csv')
#https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html
